# %%
import numpy as np 
import pandas as pd

# %%
#https://www.kaggle.com/sudalairajkumar/covid19-in-india
df = pd.read_csv('covid_19_india.csv')

# %%
df = df.drop(columns=['ConfirmedIndianNational', 'ConfirmedForeignNational'])

# %%
#lc stands for latest count
lc = df.loc[df['Date'] == "18/04/20"]
lc
# Out:
#        Sno      Date     Time         State/UnionTerritory  \
# 1058  1059  18/04/20  5:00 PM  Andaman and Nicobar Islands
# 1059  1060  18/04/20  5:00 PM               Andhra Pradesh
# 1060  1061  18/04/20  5:00 PM            Arunachal Pradesh
# 1061  1062  18/04/20  5:00 PM                        Assam
# 1062  1063  18/04/20  5:00 PM                        Bihar
# 1063  1064  18/04/20  5:00 PM                   Chandigarh
# 1064  1065  18/04/20  5:00 PM                 Chhattisgarh
# 1065  1066  18/04/20  5:00 PM                        Delhi
# 1066  1067  18/04/20  5:00 PM                          Goa
# 1067  1068  18/04/20  5:00 PM                      Gujarat
# 1068  1069  18/04/20  5:00 PM                      Haryana
# 1069  1070  18/04/20  5:00 PM             Himachal Pradesh
# 1070  1071  18/04/20  5:00 PM            Jammu and Kashmir
# 1071  1072  18/04/20  5:00 PM                    Jharkhand
# 1072  1073  18/04/20  5:00 PM                    Karnataka
# 1073  1074  18/04/20  5:00 PM                       Kerala
# 1074  1075  18/04/20  5:00 PM                       Ladakh
# 1075  1076  18/04/20  5:00 PM               Madhya Pradesh
# 1076  1077  18/04/20  5:00 PM                  Maharashtra
# 1077  1078  18/04/20  5:00 PM                      Manipur
# 1078  1079  18/04/20  5:00 PM                    Meghalaya
# 1079  1080  18/04/20  5:00 PM                      Mizoram
# 1080  1081  18/04/20  5:00 PM                    Nagaland#
# 1081  1082  18/04/20  5:00 PM                       Odisha
# 1082  1083  18/04/20  5:00 PM                   Puducherry
# 1083  1084  18/04/20  5:00 PM                       Punjab
# 1084  1085  18/04/20  5:00 PM                    Rajasthan
# 1085  1086  18/04/20  5:00 PM                   Tamil Nadu
# 1086  1087  18/04/20  5:00 PM                    Telengana
# 1087  1088  18/04/20  5:00 PM                      Tripura
# 1088  1089  18/04/20  5:00 PM                  Uttarakhand
# 1089  1090  18/04/20  5:00 PM                Uttar Pradesh
# 1090  1091  18/04/20  5:00 PM                  West Bengal
#
#      ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 1058                       -                        -     11       0
# 1059                       -                        -     42      15
# 1060                       -                        -      0       0
# 1061                       -                        -      9       1
# 1062                       -                        -     37       2
# 1063                       -                        -      9       0
# 1064                       -                        -     24       0
# 1065                       -                        -     72      42
# 1066                       -                        -      6       0
# 1067                       -                        -     88      48
# 1068                       -                        -     43       3
# 1069                       -                        -     16       1
# 1070                       -                        -     42       5
# 1071                       -                        -      0       2
# 1072                       -                        -     92      13
# 1073                       -                        -    255       3
# 1074                       -                        -     14       0
# 1075                       -                        -     69      69
# 1076                       -                        -    331     201
# 1077                       -                        -      1       0
# 1078                       -                        -      0       1
# 1079                       -                        -      0       0
# 1080                       -                        -      0       0
# 1081                       -                        -     21       1
# 1082                       -                        -      3       0
# 1083                       -                        -     27      13
# 1084                       -                        -    183      11
# 1085                       -                        -    283      15
# 1086                       -                        -    186      18
# 1087                       -                        -      1       0
# 1088                       -                        -      9       0
# 1089                       -                        -     86      14
# 1090                       -                        -     55      10
#
#       Confirmed
# 1058         12
# 1059        603
# 1060          1
# 1061         35
# 1062         85
# 1063         21
# 1064         36
# 1065       1707
# 1066          7
# 1067       1272
# 1068        225
# 1069         38
# 1070        328
# 1071         33
# 1072        371
# 1073        396
# 1074         18
# 1075       1355
# 1076       3323
# 1077          2
# 1078         11
# 1079          1
# 1080          0
# 1081         60
# 1082          7
# 1083        202
# 1084       1229
# 1085       1323
# 1086        791
# 1087          2
# 1088         42
# 1089        969
# 1090        287

# %% [markdown]
# # Analysing Covid-19 cases in India

# %%
total_cases = lc['Confirmed'].sum()
total_cured = lc['Cured'].sum()
total_death = lc['Deaths'].sum()
total_active = total_cases - total_cured - total_death

# %%
print(f"Total Confirmed Cases - {total_cases}")
print(f"Total Active Cases - {total_active}")
print(f"Total Deaths - {total_death}")
print(f"Total Cured - {total_cured}")
# Out:
# Total Confirmed Cases - 14792
# Total Active Cases - 12289
# Total Deaths - 488
# Total Cured - 2015

# %% [markdown]
# # Distribution of Cases in India

# %%
#https://www.kaggle.com/nxrprime/styling-data-frames-covid-19-vs-conferences
lc[['State/UnionTerritory', 'Cured', 'Deaths', 'Confirmed']].style.background_gradient(cmap='Reds',subset=['Cured', 'Deaths', 'Confirmed'])
# Out:
# <style  type="text/css" >
#     #T_54def202_8238_11ea_96d1_847beb43ac05row0_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row1_col1 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row1_col2 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row1_col3 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row2_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row3_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row3_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row3_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row4_col1 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row4_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row4_col3 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row5_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row5_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row5_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row6_col1 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row6_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row6_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row7_col1 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row7_col2 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row7_col3 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row8_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row8_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row8_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row9_col1 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row9_col2 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row9_col3 {
#             background-color:  #fc9070;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row10_col1 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row10_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row10_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row11_col1 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row11_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row11_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row12_col1 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row12_col2 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row12_col3 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row13_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row13_col2 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row13_col3 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row14_col1 {
#             background-color:  #fcb296;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row14_col2 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row14_col3 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row15_col1 {
#             background-color:  #c4161c;
#             color:  #f1f1f1;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row15_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row15_col3 {
#             background-color:  #fee1d4;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row16_col1 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row16_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row16_col3 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row17_col1 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row17_col2 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row17_col3 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row18_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row18_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row18_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row19_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row19_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_54def202_8238_11ea_96d1_847beb43ac05row19_col3 {
#             background-color:  #fff5f0;
